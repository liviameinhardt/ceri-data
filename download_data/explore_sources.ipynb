# %%
import pandas as pd
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon          ps         gn
# 1     Amon        rsds         gn
# 2     Amon        rlus         gn
# 3     Amon        rlds         gn
# 4     Amon         psl         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# ...

# %%
models_ = ["MIROC6", "MRI-ESM2-0", "NorESM2-MM", "GFDL-ESM4", "ACCESS-ESM1-5", "IPSL-CM6A-LR"]
[i for i in models_ if i not in df['source_id'].unique()]
# Out:
# []

# %%
df_ta = df.query("activity_id=='CMIP' & table_id == 'day' & variable_id == 'prc' & experiment_id != 'historical'")
df_ta
# Out:
#        activity_id institution_id        source_id experiment_id member_id  \
# 797           CMIP   CNRM-CERFACS       CNRM-CM6-1       1pctCO2  r1i1p1f2
# 1960          CMIP      NOAA-GFDL         GFDL-CM4     piControl  r1i1p1f1
# 3048          CMIP      NOAA-GFDL         GFDL-CM4     piControl  r1i1p1f1
# 10220         CMIP      NOAA-GFDL         GFDL-CM4          amip  r1i1p1f1
# 10240         CMIP      NOAA-GFDL         GFDL-CM4          amip  r1i1p1f1
# ...            ...            ...              ...           ...       ...
# 513084        CMIP            NCC       NorESM2-LM  abrupt-4xCO2  r1i1p1f1
# 514664        CMIP        AS-RCEC          TaiESM1  abrupt-4xCO2  r1i1p1f1
# 514813        CMIP           IPSL  IPSL-CM5A2-INCA     piControl  r1i1p1f1
# 515217        CMIP           CMCC        CMCC-ESM2     piControl  r1i1p1f1
# 515285        CMIP           CMCC     CMCC-CM2-HR4       1pctCO2  r1i1p1f1
#
#        table_id variable_id grid_label  \
# ...

# %%
df_ta['experiment_id'].unique()
# Out:
# array(['1pctCO2', 'piControl', 'amip', 'abrupt-4xCO2'], dtype=object)
